# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("experiment.csv")

print(df.shape[0])
df.plot()

plt.savefig("experiment-400-10000-3-0_2-maxplay_25000-slowmove_punish_0_0001.pdf")
#plt.savefig("experiment-400-3-0_2-maxplay_25000-slowmove_punish_0_0001.pdf")
#plt.savefig("experiment-400-3-0_2.pdf")
#plt.savefig("experiment-400-1-0_1.pdf")
# Out:
# 10000
